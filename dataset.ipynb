# %%
# !pip install SpeechRecognition
# Out:
# ...
#      |████████████████████████████████| 32.8MB 145kB/s
# ...

# %%
import pandas as pd
from glob import glob
import os
import speech_recognition as sr
import pandas as pd

# %%
data_dir='/content/drive/MyDrive/Capstone/Curated_dataset'

# %%
for dirname, _, filenames in os.walk(data_dir):
    for filename in filenames:
        p=(os.path.join(dirname, filename))
        print(p)
# Out:
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-159.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-162.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-161.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-160.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-163.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-152.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-154.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-153.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-157.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-155.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-156.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-158.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-164.flac
# /content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত/A-006.flac
# ...

# %%
data='/content/drive/MyDrive/Capstone/Curated_dataset/উত্তেজিত'

# %%
dir_list=os.listdir(data)

dir_list
# Out:
# ['Ex-014.flac',
#  'Ex-001.flac',
#  'Ex-003.flac',
#  'Ex-016.flac',
#  'Ex-004.flac',
#  'Ex-011.flac',
#  'Ex-005.flac',
#  'Ex-013.flac',
#  'Ex-017.flac',
#  'Ex-008.flac',
#  'Ex-012.flac',
#  'Ex-002.flac',
#  'Ex-018.flac',
#  'Ex-009.flac',
#  'Ex-006.flac',
#  'Ex-007.flac',
#  'Ex-010.flac',
#  'Ex-015.flac',
#  'Ex-038.flac',
#  'Ex-026.flac',
#  'Ex-028.flac',
#  'Ex-019.flac',
#  'Ex-048.flac',
#  'Ex-046.flac',
#  'Ex-021.flac',
#  'Ex-025.flac',
#  'Ex-044.flac',
#  'Ex-041.flac',
#  'Ex-034.flac',
#  'Ex-036.flac',
#  'Ex-042.flac',
#  'Ex-027.flac',
#  'Ex-047.flac',
#  'Ex-020.flac',
#  'Ex-024.flac',
#  'Ex-039.flac',
#  'Ex-032.flac',
#  'Ex-045.flac',
#  'Ex-029.flac',
#  'Ex-031.flac',
#  'Ex-035.flac',
#  'Ex-030.flac',
#  'Ex-033.flac',
#  'Ex-043.flac',
#  'Ex-040.flac',
#  'Ex-022.flac',
#  'Ex-037.flac',
#  'Ex-023.flac',
#  'Ex-049.flac',
#  'Ex-054.flac',
#  'Ex-053.flac',
#  'Ex-050.flac',
#  'Ex-051.flac',
#  'Ex-052.flac',
#  'Ex-057.flac',
# ...

# %%
path=[]
emotion=[]

for i in dir_list:
     path.append(data+i)
     emotion.append("উত্তেজিত")

new_dataset2=pd.DataFrame(path,columns=['path'])
new_dataset2['Text']=senText
new_dataset2['class']=pd.DataFrame(emotion)

new_dataset2
# Out:
#                                                   path  ...     class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# ..                                                 ...  ...       ...
# 152  /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 153  /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 154  /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 155  /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
# 156  /content/drive/MyDrive/Capstone/Curated_datase...  ...  উত্তেজিত
#
# [157 rows x 3 columns]

# %%
data1='/content/drive/MyDrive/Capstone/Curated_dataset/খুশি'

# %%
dir_list=os.listdir(data1)

dir_list
# Out:
# ['H-004.flac',
#  'H-008.flac',
#  'H-010.flac',
#  'H-003.flac',
#  'H-015.flac',
#  'H-029.flac',
#  'H-018.flac',
#  'H-019.flac',
#  'H-002.flac',
#  'H-023.flac',
#  'H-025.flac',
#  'H-009.flac',
#  'H-012.flac',
#  'H-022.flac',
#  'H-031.flac',
#  'H-005.flac',
#  'H-006.flac',
#  'H-014.flac',
#  'H-001.flac',
#  'H-024.flac',
#  'H-027.flac',
#  'H-030.flac',
#  'H-013.flac',
#  'H-028.flac',
#  'H-020.flac',
#  'H-021.flac',
#  'H-017.flac',
#  'H-016.flac',
#  'H-007.flac',
#  'H-033.flac',
#  'H-011.flac',
#  'H-026.flac',
#  'H-039.flac',
#  'H-040.flac',
#  'H-051.flac',
#  'H-046.flac',
#  'H-055.flac',
#  'H-044.flac',
#  'H-036.flac',
#  'H-037.flac',
#  'H-052.flac',
#  'H-047.flac',
#  'H-043.flac',
#  'H-042.flac',
#  'H-041.flac',
#  'H-054.flac',
#  'H-050.flac',
#  'H-056.flac',
#  'H-049.flac',
#  'H-048.flac',
#  'H-032.flac',
#  'H-034.flac',
#  'H-057.flac',
#  'H-035.flac',
#  'H-053.flac',
#  'H-038.flac',
#  'H-045.flac',
#  'H-063.flac',
# ...

# %%
path=[]
emotion=[]

for i in dir_list:
     path.append(data1+i)
     emotion.append("খুশি")

new_dataset3=pd.DataFrame(path,columns=['path'])
new_dataset3['Text']=senText1
new_dataset3['class']=pd.DataFrame(emotion)

new_dataset3
# Out:
#                                                   path  ... class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# ..                                                 ...  ...   ...
# 152  /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 153  /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 154  /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 155  /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
# 156  /content/drive/MyDrive/Capstone/Curated_datase...  ...  খুশি
#
# [157 rows x 3 columns]

# %%
data2='/content/drive/MyDrive/Capstone/Curated_dataset/দুঃখিত'

# %%
dir_list=os.listdir(data2)

dir_list
# Out:
# ['S-004.flac',
#  'S-005.flac',
#  'S-007.flac',
#  'S-003.flac',
#  'S-006.flac',
#  'S-008.flac',
#  'S-001.flac',
#  'S-002.flac',
#  'S-016.flac',
#  'S-022.flac',
#  'S-013.flac',
#  'S-009.flac',
#  'S-018.flac',
#  'S-021.flac',
#  'S-010.flac',
#  'S-011.flac',
#  'S-023.flac',
#  'S-015.flac',
#  'S-012.flac',
#  'S-017.flac',
#  'S-020.flac',
#  'S-024.flac',
#  'S-014.flac',
#  'S-019.flac',
#  'S-033.flac',
#  'S-034.flac',
#  'S-030.flac',
#  'S-035.flac',
#  'S-036.flac',
#  'S-028.flac',
#  'S-037.flac',
#  'S-029.flac',
#  'S-025.flac',
#  'S-032.flac',
#  'S-026.flac',
#  'S-031.flac',
#  'S-027.flac',
#  'S-038.flac',
#  'S-039.flac',
#  'S-047.flac',
#  'S-045.flac',
#  'S-043.flac',
#  'S-054.flac',
#  'S-042.flac',
#  'S-046.flac',
#  'S-050.flac',
#  'S-056.flac',
#  'S-049.flac',
#  'S-044.flac',
#  'S-053.flac',
#  'S-048.flac',
#  'S-052.flac',
#  'S-040.flac',
#  'S-051.flac',
#  'S-041.flac',
#  'S-068.flac',
#  'S-058.flac',
#  'S-071.flac',
# ...

# %%
path=[]
emotion=[]

for i in dir_list:
     path.append(data2+i)
     emotion.append("দুঃখিত")

new_dataset4=pd.DataFrame(path,columns=['path'])
new_dataset4['Text']=senText2
new_dataset4['class']=pd.DataFrame(emotion)

new_dataset4
# Out:
#                                                   path  ...   class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# ..                                                 ...  ...     ...
# 152  /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 153  /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 154  /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 155  /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
# 156  /content/drive/MyDrive/Capstone/Curated_datase...  ...  দুঃখিত
#
# [157 rows x 3 columns]

# %%
data3='/content/drive/MyDrive/Capstone/Curated_dataset/নিরপেক্ষ'

# %%
dir_list=os.listdir(data3)
dir_list

# %%
path=[]
emotion=[]

for i in dir_list:
     path.append(data3+i)
     emotion.append("নিরপেক্ষ")

new_dataset5=pd.DataFrame(path,columns=['path'])
new_dataset5['Text']=senText3
new_dataset5['class']=pd.DataFrame(emotion)
new_dataset5
# Out:
#                                                   path  ...     class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# ..                                                 ...  ...       ...
# 152  /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 153  /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 154  /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 155  /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
# 156  /content/drive/MyDrive/Capstone/Curated_datase...  ...  নিরপেক্ষ
#
# [157 rows x 3 columns]

# %%
data4='/content/drive/MyDrive/Capstone/Curated_dataset/রাগান্বিত'

# %%
dir_list=os.listdir(data4)
dir_list

# %%
path=[]
emotion=[]

for i in dir_list:
     path.append(data4+i)
     emotion.append("রাগান্বিত")

new_dataset6=pd.DataFrame(path,columns=['path'])
new_dataset6['Text']=senText4
new_dataset6['class']=pd.DataFrame(emotion)
new_dataset6
# Out:
#                                                   path  ...      class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# ..                                                 ...  ...        ...
# 152  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 153  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 154  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 155  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 156  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
#
# [157 rows x 3 columns]

# %%
new_dataset2=pd.concat([new_dataset2,new_dataset3,new_dataset4,new_dataset5,new_dataset6],axis=0, ignore_index=True)
new_dataset2
# Out:
#                                                   path  ...      class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# ..                                                 ...  ...        ...
# 780  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 781  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 782  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 783  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 784  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
#
# [785 rows x 3 columns]

# %%
new_dataset2.to_csv("Dataset.csv",index=False)

# %%
pd.read_csv('Dataset.csv')
# Out:
#                                                   path  ...      class
# 0    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 1    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 2    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 3    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# 4    /content/drive/MyDrive/Capstone/Curated_datase...  ...   উত্তেজিত
# ..                                                 ...  ...        ...
# 780  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 781  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 782  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 783  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
# 784  /content/drive/MyDrive/Capstone/Curated_datase...  ...  রাগান্বিত
#
# [785 rows x 3 columns]

# %%
dataset_df_1='/content/drive/MyDrive/Capstone/Curated_dataset/উত্তেজিত'
text=''
sentence=[]
for dirname, _, filenames in os.walk(dataset_df_1):
    for filename in filenames:
          p=(os.path.join(dirname, filename))
        
          r=sr.Recognizer()
          with sr.AudioFile(p) as source:
              audio=r.record(source)
              try:
               text=r.recognize_google(audio, language='bn_BD')
              except sr.UnknownValueError:
               text = "Google Speech Recognition could not understand audio"
        
          
          #print(text)
          sentence.append(text)
sentence

# %%
senText=pd.DataFrame(sentence,columns=['text'])
senText

# %%
dataset_df_2='/content/drive/MyDrive/Capstone/Curated_dataset/খুশি'
text1=''
sentence1=[]
for dirname, _, filenames in os.walk(dataset_df_2):
    for filename in filenames:
          p=(os.path.join(dirname, filename))
        
          r=sr.Recognizer()
          with sr.AudioFile(p) as source:
              audio=r.record(source)
              try:
               text1=r.recognize_google(audio, language='bn_BD')
              except sr.UnknownValueError:
               text1 = "Google Speech Recognition could not understand audio"
        
          
          #print(text)
          sentence1.append(text1)
sentence1

# %%
senText1=pd.DataFrame(sentence1,columns=['text'])
senText1
# Out:
#                                                   text
# 0                                        আলম কেমন আছিস
# 1                 মাশাল্লাহ নাটক রান্নার হাত অনেক ভালো
# 2                               চল আমরা বিয়ে করে ফেলি
# 3                           ফুল যেমনই হোক তেমনই সুন্দর
# 4                          সাজগোজে সবকিছুই আমার প্রিয়
# ..                                                 ...
# 185                     এসেছিল পৃথিবীতে এক ধরনের বিষয়
# 186  আপনাদেরকে দেখে আমার অনেক পুরনো দিনের কথা মনে প...
# 187  আল্লাহর কাছে একটাই চাওয়া ভালো থাকুক পৃথিবীর স...
# 188  ধন্যবাদ 600 মানুষকে যারা আমার ভালোবাসার আগে সম...
# 189  সুপ্রভাত গুড মর্নিং প্রথমেই আমি অশেষ ধন্যবাদ জ...
#
# [190 rows x 1 columns]

# %%
dataset_df_3=data2
text2=''
sentence2=[]
for dirname, _, filenames in os.walk(dataset_df_3):
    for filename in filenames:
          p=(os.path.join(dirname, filename))
        
          r=sr.Recognizer()
          with sr.AudioFile(p) as source:
              audio=r.record(source)
              try:
               text2=r.recognize_google(audio, language='bn_BD')
              except sr.UnknownValueError:
               text2 = "Google Speech Recognition could not understand audio"
        
          
          #print(text)
          sentence2.append(text2)
sentence2

# %%
senText2=pd.DataFrame(sentence2,columns=['text'])
senText2

# %%
dataset_df_4=data3
text3=''
sentence3=[]
for dirname, _, filenames in os.walk(dataset_df_4):
    for filename in filenames:
          p=(os.path.join(dirname, filename))
        
          r=sr.Recognizer()
          with sr.AudioFile(p) as source:
              audio=r.record(source)
              try:
               text3=r.recognize_google(audio, language='bn_BD')
              except sr.UnknownValueError:
               text3 = "Google Speech Recognition could not understand audio"
        
          
          #print(text)
          sentence3.append(text3)
sentence3

# %%
senText3=pd.DataFrame(sentence3,columns=['text'])
senText3
# Out:
#                                                   text
# 0                  আমি চিন্তা করেছি আরও দুটি টিউশন করব
# 1                    এটা সত্যি যে আমাদের খুব স্বচ্ছলতা
# 2                                    কি পড়াশুনা করছেন
# 3                          বাবাকে কিছু জানাতে পারছি না
# 4                                         কি নাম আপনার
# ..                                                 ...
# 196                                       নাম কি তোমার
# 197                                  কি করে তুমি বোঝনা
# 198                      তুমি আগের থেকে মোটা হয়ে গেছো
# 199                                               টাকা
# 200  আপা কিছু বলেছে আমি রান্না করেছি আমি কিন্তু রান...
#
# [201 rows x 1 columns]

# %%
dataset_df_5=data4
text4=''
sentence4=[]
for dirname, _, filenames in os.walk(dataset_df_5):
    for filename in filenames:
          p=(os.path.join(dirname, filename))
        
          r=sr.Recognizer()
          with sr.AudioFile(p) as source:
              audio=r.record(source)
              try:
               text4=r.recognize_google(audio, language='bn_BD')
              except sr.UnknownValueError:
               text4 = "Google Speech Recognition could not understand audio"
        
          
          #print(text)
          sentence4.append(text4)
sentence4
# Out:
# ['আপনি যে সময়টা আমাকে দিচ্ছেন সেই সময় আমি কাজটা শেষ করতে পারবো না',
#  'আপনি আমাকে জিজ্ঞেস করবে না যে বেতন ঢুকতে পারি',
#  'আপনি বুঝতে পারছেন',
#  'আপনার পছন্দ-অপছন্দ বিউটা অফিস চলবে না তাইনা',
#  'Google Speech Recognition could not understand audio',
#  'ফটাফট আজকের ম্যাডামের তারিখে হবে',
#  'চেনা মানুষের',
#  'মানসিক রোগ হয়',
#  'এতো মেয়ে দেখলে ওই অ্যাপটা তো তোমরা পছন্দ করতে পারোনি',
#  'অমনোযোগী কেন',
#  'আমি জানতে চেয়েছি আপনার সকাল হয় কয়টায়',
#  'তুমি তোমার ছেলের মতো শুধু মানে মানে করো কেন একবার বললে তুমি বোঝনা',
#  'এটা কি আপনি ঘুমাবেন',
#  'আমি আমার বাবার পছন্দের ছেলেকে বিয়ে করে ফেলবো',
#  'তুমি এখন কি করতেছ',
#  'আমি যখন বাসা থেকে বের হই',
#  'বাড়িতে নেই মানে',
#  'বলছি না তুমি আমার জন্য ব্রিজের উপরে থাকবা',
#  'আমাকে ফোন করে কি বলছিলা',
#  'আমি যদি বলি তুমি আজকে ক্লাবে যাবে না',
#  'ওকে মত চাকরি দেন না',
#  'টিচার স্টুডেন্ট মধ্যে আর কোন রিলেশন হতে পারেনা',
#  'বুঝলাম তো',
#  'কেন তোমার আমাকে পছন্দ হয়',
#  'তুমি বুঝি নাই',
#  'আমি কত সালে চাহিদা',
# ...

# %%
senText4=pd.DataFrame(sentence4,columns=['text'])
senText4
# Out:
#                                                   text
# 0    আপনি যে সময়টা আমাকে দিচ্ছেন সেই সময় আমি কাজট...
# 1        আপনি আমাকে জিজ্ঞেস করবে না যে বেতন ঢুকতে পারি
# 2                                    আপনি বুঝতে পারছেন
# 3          আপনার পছন্দ-অপছন্দ বিউটা অফিস চলবে না তাইনা
# 4    Google Speech Recognition could not understand...
# ..                                                 ...
# 196  আমি আপনাকে নিষেধ করেছি আপনি কি আসবেন না বেরিয়...
# 197             এই কি বলছে থাপ্পড় আবি বলার মত কেউ নাই
# 198  Google Speech Recognition could not understand...
# 199  খবরদার আমাকে ফলো করবেন না আমি যেন আপনাকে না দে...
# 200                                            গজল গজল
#
# [201 rows x 1 columns]
